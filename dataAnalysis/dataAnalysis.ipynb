# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./0/flow.txt", sep=',', index_col=0, header=0)
data
# Out:
#       bandwidth  startTime  sendTime
# id
# 0           736         30         5
# 1           805         27        47
# 2           314         47        47
# 3           895         26         2
# 4           693         28         4
# ...         ...        ...       ...
# 4995         12          8        43
# 4996         40         17        29
# 4997        293         14        33
# 4998        564         26        13
# 4999        908          8         2
#
# [5000 rows x 3 columns]

# %%
data[data['startTime'] == 26].hist('sendTime')
# Out:
# array([[<AxesSubplot:title={'center':'sendTime'}>]], dtype=object)

# %%
result = pd.read_csv("./0/result.txt", sep=',', header=None, index_col=0)
result
# Out:
#       1    2
# 0
# 934   3    0
# 2272  3    0
# 2761  3    0
# 3480  3    0
# 2770  3    0
# ...  ..  ...
# 4547  0  154
# 4081  4  156
# 3389  2  156
# 111   0  156
# 0     0    0
#
# [5000 rows x 2 columns]

# %%
merge = pd.merge(data, result, left_index=True, right_index=True, how='outer')
merge
# Out:
#       bandwidth  startTime  sendTime    1      2
# 0           736         30         5  0.0   30.0
# 0           736         30         5  0.0    0.0
# 1           805         27        47  4.0  113.0
# 2           314         47        47  0.0   47.0
# 3           895         26         2  0.0   26.0
# ...         ...        ...       ...  ...    ...
# 4995         12          8        43  0.0   18.0
# 4996         40         17        29  0.0   17.0
# 4997        293         14        33  0.0   14.0
# 4998        564         26        13  0.0   26.0
# 4999        908          8         2  0.0    8.0
#
# [5001 rows x 5 columns]

# %%
merge.to_csv("./results.csv")

# %% [markdown]
# 纯sendTime
# 第0号文件：
# 理论最优：23272.5
# 实际结果：23644
# 分数：22.8638
# 理论最高分数：22.8998
#
# 第1号文件：
# 理论最优：21025.7
# 实际结果：21305
# 分数：23.1028
# 理论最高分数：23.1334
#
# 第2号文件：
# 理论最优：23567.5
# 实际结果：23907
# 分数：22.8387
# 理论最高分数：22.8712
#
# 第3号文件：
# 理论最优：7415.18
# 实际结果：7549
# 分数：25.7872
# 理论最高分数：25.839
#
# 第4号文件：
# 理论最优：5740.79
# 实际结果：5816
# 分数：26.5631
# 理论最高分数：26.603
#
# 第5号文件：
# 理论最优：31342.8
# 实际结果：31873
# 分数：22.2053
# 理论最高分数：22.2413
#
# 第6号文件：
# 理论最优：11341.5
# 实际结果：11486
# 分数：24.6295
# 理论最高分数：24.6629
#
# 第7号文件：
# 理论最优：38544.5
# 实际结果：39106
# 分数：21.7758
# 理论最高分数：21.8057
#
# 第8号文件：
# 理论最优：13923.4
# 实际结果：14042
# 分数：24.1113
# 理论最高分数：24.1328
#
# 第9号文件：
# 理论最优：8263.38
# 实际结果：8350
# 分数：25.4992
# 理论最高分数：25.5287
#
# 总和理论最优：184437
# 总和实际结果：187078
# 总分数：23.93769118
# 总理论最高分数：23.97178163
